# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("data_science_project.csv")

# %%
data.head()
# Out:
#   Fund Number Market Cap    Type     Risk   Assets  Turnover Ratio(%)     SD  \
# 0       RF001      Large  Growth  Average   654.66               57.0  10.90
# 1       RF002      Large  Growth      Low  1999.02                0.0   9.44
# 2       RF003      Large  Growth  Average    97.70               29.0  10.50
# 3       RF004      Large  Growth  Average  1079.96               58.0  11.04
# 4       RF005      Large  Growth  Average  9861.25              103.0   9.88
#
#    Sharpe Ratio  1YrReturn%  3YrReturn%  5YrReturn%  10YrReturn%  \
# 0          1.59        9.20       18.20       15.92         9.53
# 1          1.32       13.31       12.75       12.27         9.70
# 2          1.28        8.18       13.79       13.83         6.93
# 3          1.32       11.85       15.00       15.50        11.35
# 4          1.45       13.07       14.81       14.59         8.20
#
#    Expense Ratio Star Rating
# 0           1.11        Five
# 1           1.10        Four
# ...

# %% [markdown]
# Present which stock has highest risk and return

# %%
high_risk=data[data["Risk"]=="High"]

# %%
high_risk["Fund Number"]
# Out:
# 49     RF050
# 83     RF084
# 84     RF085
# 85     RF086
# 103    RF104
#        ...
# 399    RF400
# 400    RF401
# 401    RF402
# 403    RF404
# 406    RF407
# Name: Fund Number, Length: 70, dtype: object

# %%
data["1YrReturn%"].max()
# Out:
# 21.7

# %%
data[data["1YrReturn%"]==21.7]
# Out:
#    Fund Number Market Cap    Type     Risk   Assets  Turnover Ratio(%)     SD  \
# 55       RF056      Large  Growth  Average  1153.55               76.0  10.82
#
#     Sharpe Ratio  1YrReturn%  3YrReturn%  5YrReturn%  10YrReturn%  \
# 55           1.8        21.7       20.68       19.65         9.94
#
#     Expense Ratio Star Rating
# 55           0.87        Five

# %%
data["3YrReturn%"].max()
# Out:
# 30.89

# %%
data[data["3YrReturn%"]==30.89]
# Out:
#     Fund Number Market Cap   Type     Risk   Assets  Turnover Ratio(%)     SD  \
# 315       RF316    Mid-Cap  Value  Average  2075.38               17.0  10.57
#
#      Sharpe Ratio  1YrReturn%  3YrReturn%  5YrReturn%  10YrReturn%  \
# 315          1.72        6.71       30.89        14.2         4.54
#
#      Expense Ratio Star Rating
# 315           1.56       Three

# %%
data["5YrReturn%"].max()
# Out:
# 22.83

# %%
data[data["3YrReturn%"]==22.83]
# Out:
# Empty DataFrame
# Columns: [Fund Number, Market Cap, Type, Risk, Assets, Turnover Ratio(%), SD, Sharpe Ratio, 1YrReturn%, 3YrReturn%, 5YrReturn%, 10YrReturn%, Expense Ratio, Star Rating]
# Index: []

# %%
data["10YrReturn%"].max()
# Out:
# 17.11

# %%
data[data["3YrReturn%"]==17.11]
# Out:
# Empty DataFrame
# Columns: [Fund Number, Market Cap, Type, Risk, Assets, Turnover Ratio(%), SD, Sharpe Ratio, 1YrReturn%, 3YrReturn%, 5YrReturn%, 10YrReturn%, Expense Ratio, Star Rating]
# Index: []

# %%
# Stock wise groth on year to year basis

# %%
data["Risk"].unique()
# Out:
# array(['Average', 'Low', 'High'], dtype=object)

# %%
data[data["Risk"]=="Average"]
# Out:
#     Fund Number Market Cap    Type     Risk   Assets  Turnover Ratio(%)  \
# 0         RF001      Large  Growth  Average   654.66               57.0
# 2         RF003      Large  Growth  Average    97.70               29.0
# 3         RF004      Large  Growth  Average  1079.96               58.0
# 4         RF005      Large  Growth  Average  9861.25              103.0
# 5         RF006      Large  Growth  Average  2355.65               25.0
# ..          ...        ...     ...      ...      ...                ...
# 396       RF397      Small   Value  Average   325.74               68.0
# 397       RF398      Small   Value  Average    75.01                0.0
# 402       RF403      Small   Value  Average   460.63               40.0
# 404       RF405      Small   Value  Average  1862.39               44.0
# 405       RF406      Small   Value  Average  1172.08              121.0
#
#         SD  Sharpe Ratio  1YrReturn%  3YrReturn%  5YrReturn%  10YrReturn%  \
# ...

# %%
data[data["Risk"]=="Low"]
# Out:
#     Fund Number Market Cap    Type Risk    Assets  Turnover Ratio(%)    SD  \
# 1         RF002      Large  Growth  Low   1999.02               0.00  9.44
# 9         RF010      Large  Growth  Low   3503.40              47.31  9.03
# 17        RF018      Large  Growth  Low    105.29               6.29  9.39
# 41        RF042      Large  Growth  Low   1732.57             124.00  9.20
# 59        RF060      Large  Growth  Low   3889.00              12.00  8.97
# 61        RF062      Large  Growth  Low    118.21              32.00  9.42
# 66        RF067      Large  Growth  Low    724.40              59.00  9.42
# 70        RF071      Large  Growth  Low   5275.93              14.10  9.40
# 75        RF076      Large  Growth  Low    143.21              52.00  8.90
# 98        RF099      Large  Growth  Low     30.96               7.49  9.17
# 100       RF101      Large  Growth  Low    124.67              14.00  9.35
# ...

# %%
data[data["Risk"]=="High"]
# Out:
#     Fund Number Market Cap    Type  Risk    Assets  Turnover Ratio(%)     SD  \
# 49        RF050      Large  Growth  High  12260.32              106.0  14.07
# 83        RF084      Large  Growth  High   3412.00               31.0  13.62
# 84        RF085      Large  Growth  High    226.62               21.0  13.17
# 85        RF086      Large  Growth  High    367.38               39.0  14.51
# 103       RF104      Large  Growth  High   4129.36              146.0  13.05
# ..          ...        ...     ...   ...       ...                ...    ...
# 399       RF400      Small   Value  High    802.03               51.0  13.36
# 400       RF401      Small   Value  High     19.29              506.0  13.18
# 401       RF402      Small   Value  High     20.01              658.0  15.36
# 403       RF404      Small   Value  High     97.16               32.0  13.57
# 406       RF407      Small   Value  High     29.01               60.0  13.54
#
# ...
